# %% [markdown]
# # Render LaTeX to SVG with matplotlib backend
#
# We use matplotlib's mathtext system and SVG backend to generate an SVG rendering of LaTeX code.

# %%
from matplotlib.backends.backend_svg import RendererSVG
from matplotlib.font_manager import FontProperties
from io import StringIO
from IPython.display import display_svg, display_html

# %%
fp = FontProperties()

s = r"$D^{\ast\ast}\ell\nu$"

# get bounding box of rendered text
r = RendererSVG(0, 0, StringIO())
w, h, _ = r.get_text_width_height_descent(s, fp, ismath=True)

with StringIO() as f:
    # render LaTeX as path
    r = RendererSVG(w, h, f)
    r.draw_text(r.new_gc(), 0, h, s, fp, angle=0, ismath=True)
    f.seek(0)
    svg_code = f.read()

display_html(svg_code, raw=True)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" width="32.9pt" height="8.5pt" viewBox="0 0 32.9 8.5" xmlns="http://www.w3.org/2000/svg" version="1.1">
#  <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-05-13T09:44:49.847495</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.8.4, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <!-- $D^{\ast\ast}\ell\nu$ -->
#  <g transform="translate(0 8.5) scale(0.1 -0.1)">
#   <defs>
#    <path id="DejaVuSans-Oblique-44" d="M 1081 4666
# L 2438 4666
# Q 3519 4666 4070 4208
# Q 4622 3750 4622 2847
# Q 4622 2250 4412 1698
# Q 4203 1147 3834 769
# Q 3463 381 2891 190
# Q 2319 0 1538 0
# L 172 0
# L 1081 4666
# z
# M 1613 4147
# L 909 519
# L 1734 519
# Q 2794 519 3375 1128
# Q 3956 1738 3956 2847
# Q 3956 3519 3581 3833
# Q 3206 4147 2406 4147
# L 1613 4147
# z
# " transform="scale(0.015625)"/>
#    <path id="DejaVuSans-2217" d="M 2153 2006
# L 816 2778
# L 1081 3238
# L 2419 2466
# L 2419 4013
# L 2944 4013
# L 2944 2466
# L 4281 3238
# L 4547 2778
# L 3209 2006
# L 4547 1234
# L 4281 775
# L 2944 1547
# L 2944 0
# L 2419 0
# L 2419 1547
# L 1081 775
# L 816 1234
# L 2153 2006
# z
# " transform="scale(0.015625)"/>
#    <path id="DejaVuSans-Oblique-2113" d="M 950 838
# Q 1078 213 1350 213
# Q 1531 213 1766 572
# L 2181 572
# Q 1994 253 1775 88
# Q 1538 -91 1319 -91
# Q 831 -91 634 344
# L 400 0
# L -88 0
# Q 250 459 500 888
# Q 469 1131 469 1397
# Q 469 1872 566 2347
# Q 931 4131 1256 4497
# Q 1481 4750 1866 4750
# Q 2256 4750 2256 4209
# Q 2253 3966 2197 3675
# Q 1972 2484 950 838
# z
# M 947 1656
# Q 1531 2744 1709 3613
# Q 1803 4072 1803 4191
# Q 1803 4406 1725 4406
# Q 1384 4134 1081 2516
# Q 997 2063 947 1656
# z
# " transform="scale(0.015625)"/>
#    <path id="DejaVuSans-Oblique-3bd" d="M 959 0
# L 572 3500
# L 1191 3500
# L 1522 563
# Q 1972 950 2391 1488
# Q 2706 1891 2788 2241
# Q 2825 2406 2809 2719
# Q 2794 3091 2544 3500
# L 3125 3500
# L 3125 3500
# Q 3288 3222 3353 2834
# Q 3416 2478 3369 2234
# Q 3250 1622 2719 1075
# Q 2025 363 1572 0
# L 959 0
# z
# " transform="scale(0.015625)"/>
#   </defs>
#   <use xlink:href="#DejaVuSans-Oblique-44" transform="translate(0 0.826562)"/>
#   <use xlink:href="#DejaVuSans-2217" transform="translate(84.018724 39.107812) scale(0.7)"/>
#   <use xlink:href="#DejaVuSans-2217" transform="translate(156.308763 39.107812) scale(0.7)"/>
#   <use xlink:href="#DejaVuSans-Oblique-2113" transform="translate(231.333177 0.826562)"/>
#   <use xlink:href="#DejaVuSans-Oblique-3bd" transform="translate(272.641771 0.826562)"/>
#  </g>

# %% [markdown]
# We can insert the SVG image into HTML layouts, for example, into an HTML table.

# %%
display_html(f"""
<html>
<body>
<table>
<tr>
    <td> {svg_code} </td> <td> foo </td>
</tr>
<tr>
    <td> bar </td> <td> baz </td>
</tr>
</table>
</body>
</html>
""", raw=True)
# Out:
# <html>
# <body>
# <table>
# <tr>
#     <td> <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" width="32.9pt" height="8.5pt" viewBox="0 0 32.9 8.5" xmlns="http://www.w3.org/2000/svg" version="1.1">
#  <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-05-13T09:44:49.847495</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.8.4, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <!-- $D^{\ast\ast}\ell\nu$ -->
#  <g transform="translate(0 8.5) scale(0.1 -0.1)">
#   <defs>
#    <path id="DejaVuSans-Oblique-44" d="M 1081 4666
# L 2438 4666
# Q 3519 4666 4070 4208
# Q 4622 3750 4622 2847
# Q 4622 2250 4412 1698
# Q 4203 1147 3834 769
# Q 3463 381 2891 190
# Q 2319 0 1538 0
# L 172 0
# L 1081 4666
# z
# M 1613 4147
# L 909 519
# L 1734 519
# Q 2794 519 3375 1128
# Q 3956 1738 3956 2847
# Q 3956 3519 3581 3833
# Q 3206 4147 2406 4147
# L 1613 4147
# z
# " transform="scale(0.015625)"/>
#    <path id="DejaVuSans-2217" d="M 2153 2006
# L 816 2778
# L 1081 3238
# L 2419 2466
# L 2419 4013
# L 2944 4013
# L 2944 2466
# L 4281 3238
# L 4547 2778
# L 3209 2006
# L 4547 1234
# L 4281 775
# L 2944 1547
# L 2944 0
# L 2419 0
# L 2419 1547
# L 1081 775
# L 816 1234
# L 2153 2006
# z
# " transform="scale(0.015625)"/>
#    <path id="DejaVuSans-Oblique-2113" d="M 950 838
# Q 1078 213 1350 213
# Q 1531 213 1766 572
# L 2181 572
# Q 1994 253 1775 88
# Q 1538 -91 1319 -91
# Q 831 -91 634 344
# L 400 0
# L -88 0
# Q 250 459 500 888
# Q 469 1131 469 1397
# Q 469 1872 566 2347
# Q 931 4131 1256 4497
# Q 1481 4750 1866 4750
# Q 2256 4750 2256 4209
# Q 2253 3966 2197 3675
# Q 1972 2484 950 838
# z
# M 947 1656
# Q 1531 2744 1709 3613
# Q 1803 4072 1803 4191
# Q 1803 4406 1725 4406
# Q 1384 4134 1081 2516
# Q 997 2063 947 1656
# z
# " transform="scale(0.015625)"/>
#    <path id="DejaVuSans-Oblique-3bd" d="M 959 0
# L 572 3500
# L 1191 3500
# L 1522 563
# Q 1972 950 2391 1488
# Q 2706 1891 2788 2241
# Q 2825 2406 2809 2719
# Q 2794 3091 2544 3500
# L 3125 3500
# L 3125 3500
# Q 3288 3222 3353 2834
# Q 3416 2478 3369 2234
# Q 3250 1622 2719 1075
# Q 2025 363 1572 0
# L 959 0
# z
# " transform="scale(0.015625)"/>
#   </defs>
#   <use xlink:href="#DejaVuSans-Oblique-44" transform="translate(0 0.826562)"/>
#   <use xlink:href="#DejaVuSans-2217" transform="translate(84.018724 39.107812) scale(0.7)"/>
#   <use xlink:href="#DejaVuSans-2217" transform="translate(156.308763 39.107812) scale(0.7)"/>
#   <use xlink:href="#DejaVuSans-Oblique-2113" transform="translate(231.333177 0.826562)"/>
#   <use xlink:href="#DejaVuSans-Oblique-3bd" transform="translate(272.641771 0.826562)"/>
#  </g>
#  </td> <td> foo </td>
# </tr>
# <tr>
#     <td> bar </td> <td> baz </td>
# </tr>
# </table>
# </body>
# </html>
